# %%
import pandas as pd

# %%
df = pd.read_csv('covid_data_set.csv', error_bad_lines=False)

# %%
df
# Out:
#        age     sex                        city    province country  \
# 0       30    male     Chaohu City: Hefei City       Anhui   China
# 1       47    male  Baohe District: Hefei City       Anhui   China
# 2       49    male  High-Tech Zone: Hefei City       Anhui   China
# 3       47  female  High-Tech Zone: Hefei City       Anhui   China
# 4       50  female  Feidong County: Hefei City       Anhui   China
# 5      NaN     NaN                  Lu'an City       Anhui   China
# 6       42  female                 Fuyang City       Anhui   China
# 7      NaN  female                Huaibei City       Anhui   China
# 8       59  female                Huainan City       Anhui   China
# 9       30    male                  Hefei City       Anhui   China
# 10     NaN     NaN                  Lu'an City       Anhui   China
# 11      39    male                 Fuyang City       Anhui   China
# 12     NaN     NaN                 Anqing City       Anhui   China
# ...

# %%
new_df=df.dropna(subset=['age'])

# %%
final_df=new_df.drop(['Unnamed: 15', 'Unnamed: 16','Unnamed: 17', 'Unnamed: 18','Unnamed: 19', 'Unnamed: 20','Unnamed: 21', 'Unnamed: 22','Unnamed: 23'], axis=1)

# %%
final_df
# Out:
#               age     sex                        city         province  \
# 0              30    male     Chaohu City: Hefei City            Anhui
# 1              47    male  Baohe District: Hefei City            Anhui
# 2              49    male  High-Tech Zone: Hefei City            Anhui
# 3              47  female  High-Tech Zone: Hefei City            Anhui
# 4              50  female  Feidong County: Hefei City            Anhui
# 6              42  female                 Fuyang City            Anhui
# 8              59  female                Huainan City            Anhui
# 9              30    male                  Hefei City            Anhui
# 11             39    male                 Fuyang City            Anhui
# 13             38  female                Chizhou City            Anhui
# 14             45    male                 Bengbu City            Anhui
# 17             33  female          Changping District          Beijing
# ...

# %%
final_df.to_csv("clean_corona.csv",index=False)
